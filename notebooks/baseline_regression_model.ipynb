# %% [markdown]
# # 1. Mô tả
#
# *Phụng Đình* sẽ làm file này.
#
# - Xây dựng mô hình Linear Regression để làm baseline.
#
# - Trả lời câu hỏi: ...
#
#
# - Báo cáo:  trả lời câu hỏi (được không, ổn không, có thể dùng vài mẫu dữ liệu riêng để thử), thông số đánh giá mô hình, 2.5 Project Summary

# %% [markdown]
# # 2. Code

# %% [markdown]
# ## 2.1 Import

# %%
# import các thư viện cần thiết

# %% [markdown]
# ## 2.2 Đọc dữ liệu

# %% [markdown]
# ## 2.3 Huấn luyện mô hình

# %%
# cài đặt các hàm cần thiết (lớp mô hình), ...

# %% [markdown]
# # 3. Báo cáo

# %% [markdown]
# ## 3.1 Trả lời câu hỏi

# %% [markdown]
# ## 3.2 Thông số đánh giá về mô hình

# %% [markdown]
# ## 3.3 Project Summary
